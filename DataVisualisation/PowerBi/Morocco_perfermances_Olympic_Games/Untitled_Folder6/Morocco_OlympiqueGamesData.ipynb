# %%
import csv

# Données fictives basées sur la structure revisitée
data = [
    {
        "Année": 1960,
        "Ville": "Rome",
        "Pays Hôte": "Italy",
        "Nombre de Participants": 47,
        "Discipline": "Athlétisme",
        "Catégorie": "Marathon",
        "Nom de l'Athlète": "Abdeslam Radi",
        "Sexe": "Homme",
        "Rang": 2,
        "Médailles": "Argent",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 1964,
        "Ville": "Tokyo",
        "Pays Hôte": "Japon",
        "Nombre de Participants": 20,
        "Discipline": "-",
        "Catégorie": "-",
        "Nom de l'Athlète": "-",
        "Sexe": "-",
        "Rang": "-",
        "Médailles": "-",
        "Résultat Final": "-"
    },
    {
        "Année": 1968,
        "Ville": "Mexico",
        "Pays Hôte": "Mexique",
        "Nombre de Participants": 25,
        "Discipline": "-",
        "Catégorie": "-",
        "Nom de l'Athlète": "-",
        "Sexe": "-",
        "Rang": "-",
        "Médailles": "-",
        "Résultat Final": "-"
    },
    {
        "Année": 1972,
        "Ville": "Munich",
        "Pays Hôte": "Allemagne",
        "Nombre de Participants": 35,
        "Discipline": "-",
        "Catégorie": "-",
        "Nom de l'Athlète": "-",
        "Sexe": "-",
        "Rang": "-",
        "Médailles": "-",
        "Résultat Final": "-"
    },
    {
        "Année": 1976,
        "Ville": "Montréal",
        "Pays Hôte": "Canada",
        "Nombre de Participants": 9,
        "Discipline": "-",
        "Catégorie": "-",
        "Nom de l'Athlète": "-",
        "Sexe": "-",
        "Rang": "-" ,
        "Médailles": "-",
        "Résultat Final": "-"
    },
    {
        "Année": 1984,
        "Ville": "Los Angeles",
        "Pays Hôte": "USA",
        "Nombre de Participants": 34,
        "Discipline": "Athlétisme",
        "Catégorie": "400m Hales",
        "Nom de l'Athlète": "Nawal El Moutawakel",
        "Sexe": "Femme",
        "Rang": 1,
        "Médailles": "Or",
        "Résultat Final": "Gagnante"
    },
    {
        "Année": 1984,
        "Ville": "Los Angeles",
        "Pays Hôte": "USA",
        "Nombre de Participants": 34,
        "Discipline": "Athlétisme",
        "Catégorie": "5000m ",
        "Nom de l'Athlète": "Said Aouita",
        "Sexe": "Homme",
        "Rang": 1,
        "Médailles": "Or",
        "Résultat Final": "Gagnant"
    },
    {
        "Année": 1988,
        "Ville": "Séoul",
        "Pays Hôte": "Corée du Sud",
        "Nombre de Participants": 27,
        "Discipline": "Athlétisme",
        "Catégorie": "800m ",
        "Nom de l'Athlète": "Said Aouita",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 1988,
        "Ville": "Séoul",
        "Pays Hôte": "Corée du Sud",
        "Nombre de Participants": 27,
        "Discipline": "Athlétisme",
        "Catégorie": "10000m ",
        "Nom de l'Athlète": "Brahim Boutayeb",
        "Sexe": "Homme",
        "Rang": 1,
        "Médailles": "Or",
        "Résultat Final": "Gagnant"
    },
    {
        "Année": 1988,
        "Ville": "Séoul",
        "Pays Hôte": "Corée du Sud",
        "Nombre de Participants": 27,
        "Discipline": "Boxe",
        "Catégorie": "57kg ",
        "Nom de l'Athlète": "Abdellah Achik",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 1992,
        "Ville": "Barcelone",
        "Pays Hôte": "Espagne",
        "Nombre de Participants": 53,
        "Discipline": "Athlétisme",
        "Catégorie": "10000m",
        "Nom de l'Athlète": "Khalid Skah",
        "Sexe": "Homme",
        "Rang": 1,
        "Médailles": "Or",
        "Résultat Final": "Gagnant"
    },
    {
        "Année": 1992,
        "Ville": "Barcelone",
        "Pays Hôte": "Espagne",
        "Nombre de Participants": 53,
        "Discipline": "Athlétisme",
        "Catégorie": "1500m ",
        "Nom de l'Athlète": "Rachid Labsir",
        "Sexe": "Homme",
        "Rang": 2,
        "Médailles": "Argent",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 1992,
        "Ville": "Barcelone",
        "Pays Hôte": "Espagne",
        "Nombre de Participants": 53,
        "Discipline": "Boxe",
        "Catégorie": "54kg",
        "Nom de l'Athlète": "Mohamed Achik",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 1996,
        "Ville": "Atlanta",
        "Pays Hôte": "USA",
        "Nombre de Participants": 34,
        "Discipline": "Athlétisme",
        "Catégorie": "5000m ",
        "Nom de l'Athlète": "Khalid Boulami",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 1996,
        "Ville": "Atlanta",
        "Pays Hôte": "USA",
        "Nombre de Participants": 34,
        "Discipline": "Athlétisme",
        "Catégorie": "10000m ",
        "Nom de l'Athlète": "Salah Hissou",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2000,
        "Ville": "Sydney",
        "Pays Hôte": "Australie",
        "Nombre de Participants": 61,
        "Discipline": "Athlétisme",
        "Catégorie": "3000m ",
        "Nom de l'Athlète": "Ali Ezzine",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2000,
        "Ville": "Sydney",
        "Pays Hôte": "Australie",
        "Nombre de Participants": 61,
        "Discipline": "Athlétisme",
        "Catégorie": "1500m ",
        "Nom de l'Athlète": "Hicham El Guerrouj",
        "Sexe": "Homme",
        "Rang": 2,
        "Médailles": "Argent",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2000,
        "Ville": "Sydney",
        "Pays Hôte": "Australie",
        "Nombre de Participants": 61,
        "Discipline": "Athlétisme",
        "Catégorie": "800m ",
        "Nom de l'Athlète": "Nezha Bidouane",
        "Sexe": "Femme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2000,
        "Ville": "Sydney",
        "Pays Hôte": "Australie",
        "Nombre de Participants": 61,
        "Discipline": "Athlétisme",
        "Catégorie": "5000m ",
        "Nom de l'Athlète": "Brahim Lahlafi",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2000,
        "Ville": "Sydney",
        "Pays Hôte": "Australie",
        "Nombre de Participants": 61,
        "Discipline": "Boxe",
        "Catégorie": "54kg ",
        "Nom de l'Athlète": "Tahar Tamsmani",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2004,
        "Ville": "Athènes",
        "Pays Hôte": "Grèce",
        "Nombre de Participants": 55,
        "Discipline": "Athlétisme",
        "Catégorie": "800m ",
        "Nom de l'Athlète": "Benhassi Hasna",
        "Sexe": "Femme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2004,
        "Ville": "Athènes",
        "Pays Hôte": "Grèce",
        "Nombre de Participants": 55,
        "Discipline": "Athlétisme",
        "Catégorie": "1500m ",
        "Nom de l'Athlète": "Hicham El Geurrouj",
        "Sexe": "Homme",
        "Rang": 1,
        "Médailles": "Or",
        "Résultat Final": "Gagnant"
    },
    {
        "Année": 2004,
        "Ville": "Athènes",
        "Pays Hôte": "Grèce",
        "Nombre de Participants": 55,
        "Discipline": "Athlétisme",
        "Catégorie": "5000m ",
        "Nom de l'Athlète": "Hicham El Geurrouj",
        "Sexe": "Homme",
        "Rang": 1,
        "Médailles": "Or",
        "Résultat Final": "Gagnant"
    },
    {
        "Année": 2008,
        "Ville": "Pékin",
        "Pays Hôte": "Chine",
        "Nombre de Participants": 47,
        "Discipline": "Athlétisme",
        "Catégorie": "Marathon ",
        "Nom de l'Athlète": "Gharib jaouad",
        "Sexe": "Homme",
        "Rang": 2,
        "Médailles": "Argent",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2008,
        "Ville": "Pékin",
        "Pays Hôte": "Chine",
        "Nombre de Participants": 47,
        "Discipline": "Athlétisme",
        "Catégorie": "800m ",
        "Nom de l'Athlète": "Benhassi Hasna",
        "Sexe": "Femme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2012,
        "Ville": "Londres",
        "Pays Hôte": "Grande-Bretagne",
        "Nombre de Participants": 63,
        "Discipline": "Athlétisme",
        "Catégorie": "1500m ",
        "Nom de l'Athlète": "Abdelaati Iguider",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
     {
        "Année": 2016,
        "Ville": "Rio de janeiro",
        "Pays Hôte": "Brésil",
        "Nombre de Participants": 49,
        "Discipline": "Boxe",
        "Catégorie": "69kg ",
        "Nom de l'Athlète": "Rabii Mohamed",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    },
    {
        "Année": 2020,
        "Ville": "Tokyo",
        "Pays Hôte": "Japon",
        "Nombre de Participants": 48,
        "Discipline": "Athlétisme",
        "Catégorie": "3000m Steeple ",
        "Nom de l'Athlète": "Soufiane ElBakkali",
        "Sexe": "Homme",
        "Rang": 1,
        "Médailles": "Or",
        "Résultat Final": "Gagnant"
    },
    {
        "Année": 2024,
        "Ville": "Paris",
        "Pays Hôte": "France",
        "Nombre de Participants": 60,
        "Discipline": "Athlétisme",
        "Catégorie": "3000m Steeple ",
        "Nom de l'Athlète": "Soufiane ElBakkali",
        "Sexe": "Homme",
        "Rang": 1,
        "Médailles": "Or",
        "Résultat Final": "Gagnant"
    },
    {
        "Année": 2024,
        "Ville": "Paris",
        "Pays Hôte": "France",
        "Nombre de Participants": 60,
        "Discipline": "Football",
        "Catégorie": "U23 Hommes ",
        "Nom de l'Athlète": "Equipe nationale U23",
        "Sexe": "Homme",
        "Rang": 3,
        "Médailles": "Bronze",
        "Résultat Final": "Médaillé"
    }
    
]

# %%
# Nom du fichier CSV à créer
csv_file = "olympic_participation_morocco.csv"

# En-têtes du fichier CSV
headers = [
    "Année", "Ville", "Pays Hôte", "Nombre de Participants", "Discipline",
    "Catégorie", "Nom de l'Athlète", "Sexe", "Âge", "Rang", "Médailles", "Résultat Final"
]

# Écriture des données dans le fichier CSV
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=headers)
    
    # Écrire les en-têtes
    writer.writeheader()
    
    # Écrire les données
    for row in data:
        writer.writerow(row)

print(f"Le fichier {csv_file} a été créé avec succès.")
# Out:
# Le fichier olympic_participation_morocco.csv a été créé avec succès.
